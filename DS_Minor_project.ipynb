# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O

# %%
data = pd.read_csv('/content/IMDB-Movie-Data.csv')

# %%
data.head(10)
# Out:
#     Rank                                    Title                       Genre  \
# 0      1                  Guardians of the Galaxy     Action,Adventure,Sci-Fi
# 1      2                               Prometheus    Adventure,Mystery,Sci-Fi
# 2      3                                    Split             Horror,Thriller
# 3      4                                     Sing     Animation,Comedy,Family
# 4      5                            Suicide Squad    Action,Adventure,Fantasy
# 5      6                           The Great Wall    Action,Adventure,Fantasy
# 6      7                               La La Land          Comedy,Drama,Music
# 8      9                       The Lost City of Z  Action,Adventure,Biography
# 9     10                               Passengers     Adventure,Drama,Romance
# 10    11  Fantastic Beasts and Where to Find Them    Adventure,Family,Fantasy
#
#                                           Description              Director  \
# ...

# %%
data.tail(10)
# Out:
#      Rank                           Title                     Genre  \
# 990   991  Underworld: Rise of the Lycans  Action,Adventure,Fantasy
# 991   992                Taare Zameen Par        Drama,Family,Music
# 992   993            Take Me Home Tonight      Comedy,Drama,Romance
# 993   994        Resident Evil: Afterlife   Action,Adventure,Horror
# 994   995                       Project X                    Comedy
# 995   996            Secret in Their Eyes       Crime,Drama,Mystery
# 996   997                 Hostel: Part II                    Horror
# 997   998          Step Up 2: The Streets       Drama,Music,Romance
# 998   999                    Search Party          Adventure,Comedy
# 999  1000                      Nine Lives     Comedy,Family,Fantasy
#
#                                            Description            Director  \
# 990  An origins story centered on the centuries-old...  Patrick Tatopoulos
# ...

# %%
data.shape
# Out:
# (1000, 12)

# %%
print('Number of Rows',data.shape[0])
print('Number of Columns',data.shape[1])
# Out:
# Number of Rows 1000
# Number of Columns 12

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Rank                1000 non-null   int64
#  1   Title               1000 non-null   object
#  2   Genre               1000 non-null   object
#  3   Description         1000 non-null   object
#  4   Director            1000 non-null   object
#  5   Actors              1000 non-null   object
#  6   Year                1000 non-null   int64
#  7   Runtime (Minutes)   1000 non-null   int64
#  8   Rating              1000 non-null   float64
#  9   Votes               1000 non-null   int64
#  10  Revenue (Millions)  872 non-null    float64
#  11  Metascore           936 non-null    float64
# dtypes: float64(3), int64(4), object(5)
# memory usage: 93.9+ KB

# %%
data.isnull().sum()
# Out:
# Rank                    0
# Title                   0
# Genre                   0
# Description             0
# Director                0
# Actors                  0
# Year                    0
# Runtime (Minutes)       0
# Rating                  0
# Votes                   0
# Revenue (Millions)    128
# Metascore              64
# dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.heatmap(data.isnull())
plt.show()

# %% [markdown]
# Revenue and Metadata has null values in the dataset

# %%
data = data.dropna(axis=0)

# %%
sns.heatmap(data.isnull())
plt.show()

# %% [markdown]
# no null vaues in the dataset

# %%
dup_data=data.duplicated().any()
print("Are there any duplicated values in data?",dup_data)
# Out:
# Are there any duplicated values in data? False

# %%
data.describe()
# Out:
#               Rank        Year  Runtime (Minutes)      Rating         Votes  \
# count   838.000000   838.00000         838.000000  838.000000  8.380000e+02
# mean    485.247017  2012.50716         114.638425    6.814320  1.932303e+05
# std     286.572065     3.17236          18.470922    0.877754  1.930990e+05
# min       1.000000  2006.00000          66.000000    1.900000  1.780000e+02
# 25%     238.250000  2010.00000         101.000000    6.300000  6.127650e+04
# 50%     475.500000  2013.00000         112.000000    6.900000  1.368795e+05
# 75%     729.750000  2015.00000         124.000000    7.500000  2.710830e+05
# max    1000.000000  2016.00000         187.000000    9.000000  1.791916e+06
#
#        Revenue (Millions)   Metascore
# count          838.000000  838.000000
# mean            84.564558   59.575179
# std            104.520227   16.952416
# min              0.000000   11.000000
# 25%             13.967500   47.000000
# 50%             48.150000   60.000000
# ...

# %% [markdown]
# Movies with run time more than 180 minutes

# %%
print(data.columns)
data[data['Runtime (Minutes)']>=180][['Title','Director']]
# Out:
# Index(['Rank', 'Title', 'Genre', 'Description', 'Director', 'Actors', 'Year',
#        'Runtime (Minutes)', 'Rating', 'Votes', 'Revenue (Millions)',
#        'Metascore'],
#       dtype='object')
#                        Title             Director
# 82   The Wolf of Wall Street      Martin Scorsese
# 88         The Hateful Eight    Quentin Tarantino
# 311           La vie d'Adèle  Abdellatif Kechiche

# %%
#In Which Year There Was The Highest Voting?
sns.barplot(x='Year',y='Votes',data=data)
plt.title("Votes By Year")
plt.show()

# %%
#In Which Year There Was The Highest Revenue?
sns.barplot(x='Year',y='Revenue (Millions)',data=data)
plt.title("Revenue By Year")
plt.show()

# %%
#Find The Average Rating For Each Director
data.groupby('Director')['Rating'].mean().sort_values(ascending=False)
# Out:
# Director
# Christopher Nolan                   8.68
# Olivier Nakache                     8.60
# Makoto Shinkai                      8.60
# Florian Henckel von Donnersmarck    8.50
# Aamir Khan                          8.50
#                                     ...
# Sam Taylor-Johnson                  4.10
# Joey Curtis                         4.00
# George Nolfi                        3.90
# James Wong                          2.70
# Jason Friedberg                     1.90
# Name: Rating, Length: 524, dtype: float64

# %%
#Display Top 10 Lengthy Movies Title
le =data.nlargest(10,'Runtime (Minutes)')[['Title','Runtime (Minutes)']].set_index('Title')
le
# Out:
#                                           Runtime (Minutes)
# Title
# The Hateful Eight                                       187
# The Wolf of Wall Street                                 180
# La vie d'Adèle                                          180
# Cloud Atlas                                             172
# 3 Idiots                                                170
# Interstellar                                            169
# Pirates of the Caribbean: At World's End                169
# The Hobbit: An Unexpected Journey                       169
# The Curious Case of Benjamin Button                     166
# Transformers: Age of Extinction                         165

# %%
sns.barplot(x=le['Runtime (Minutes)'] ,y=le.index)
plt.title('Top 5 Lengtly Movies')
plt.show()

# %%
#Display Number of Movies Per Year
sns.countplot(x='Year',data=data)
plt.title("Number of Movies Per Year")
# Out:
# Text(0.5, 1.0, 'Number of Movies Per Year')

# %%
#Find Most Popular Movie Title (Higest Revenue)
print(data.columns)
data[data['Revenue (Millions)'].max() == data['Revenue (Millions)']]
# Out:
# Index(['Rank', 'Title', 'Genre', 'Description', 'Director', 'Actors', 'Year',
#        'Runtime (Minutes)', 'Rating', 'Votes', 'Revenue (Millions)',
#        'Metascore'],
#       dtype='object')
#     Rank                                       Title  \
# 50    51  Star Wars: Episode VII - The Force Awakens
#
#                        Genre  \
# 50  Action,Adventure,Fantasy
#
#                                           Description     Director  \
# 50  Three decades after the defeat of the Galactic...  J.J. Abrams
#
#                                                Actors  Year  \
# 50  Daisy Ridley, John Boyega, Oscar Isaac, Domhna...  2015
#
#     Runtime (Minutes)  Rating   Votes  Revenue (Millions)  Metascore
# 50                136     8.1  661608              936.63       81.0

# %%
data[data['Revenue (Millions)'].max() == data['Revenue (Millions)']]['Title']
# Out:
# 50    Star Wars: Episode VII - The Force Awakens
# Name: Title, dtype: object

# %%
#Display Top 10 Highest Rated Movie Titles And its Directors
top_10=data.nlargest(10,'Rating')[['Title','Rating','Director']].set_index('Director')
top_10
# Out:
#                                                   Title  Rating
# Director
# Christopher Nolan                       The Dark Knight     9.0
# Christopher Nolan                             Inception     8.8
# Christopher Nolan                          Interstellar     8.6
# Makoto Shinkai                            Kimi no na wa     8.6
# Olivier Nakache                        The Intouchables     8.6
# Christopher Nolan                          The Prestige     8.5
# Martin Scorsese                            The Departed     8.5
# Christopher Nolan                 The Dark Knight Rises     8.5
# Damien Chazelle                                Whiplash     8.5
# Florian Henckel von Donnersmarck    The Lives of Others     8.5

# %%
sns.barplot(x='Rating',y=top_10.index,data=top_10,hue='Director')
plt.title("Display Top 10 Highest Rated Movie Titles")
plt.show()

# %%
#Display Top 10 Highest Revenue Movie Titles
top10 = data.nlargest(10,'Revenue (Millions)')
top10.index = top10.Title
top10[['Title','Revenue (Millions)']].plot.bar(figsize=(12,4))
# Out:
# <Axes: xlabel='Title'>

# %%
#Find Average Rating of Movies Year-wise
data.columns
data1=data.groupby('Year')[['Year','Rating']].mean().sort_values(by='Rating',ascending=False).set_index('Year')
data1
# Out:
#           Rating
# Year
# 2006.0  7.143902
# 2007.0  7.140909
# 2011.0  6.945614
# 2012.0  6.933871
# 2009.0  6.911111
# 2010.0  6.894737
# 2013.0  6.832143
# 2014.0  6.822581
# 2008.0  6.708333
# 2015.0  6.674312
# 2016.0  6.644444

# %%
plt.figure(figsize=(10,5))
sns.barplot(x=data1.index,y=data1['Rating'])
plt.show()

# %%
#Classify Movies Based on Ratings [Good,Better and Best]
data.columns
# Out:
# Index(['Rank', 'Title', 'Genre', 'Description', 'Director', 'Actors', 'Year',
#        'Runtime (Minutes)', 'Rating', 'Votes', 'Revenue (Millions)',
#        'Metascore'],
#       dtype='object')

# %%
def rating(rating):
    if rating>=7.0:
        return 'Excellent'
    elif rating>=6.0:
        return 'Good'
    else:
        return 'Average'

# %%
data['rating_cat']=data['Rating'].apply(rating)
data.head()
# Out:
#    Rank                    Title                     Genre  \
# 0     1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1     2               Prometheus  Adventure,Mystery,Sci-Fi
# 2     3                    Split           Horror,Thriller
# 3     4                     Sing   Animation,Comedy,Family
# 4     5            Suicide Squad  Action,Adventure,Fantasy
#
#                                          Description              Director  \
# 0  A group of intergalactic criminals are forced ...            James Gunn
# 1  Following clues to the origin of mankind, a te...          Ridley Scott
# 2  Three girls are kidnapped by a man with a diag...    M. Night Shyamalan
# 3  In a city of humanoid animals, a hustling thea...  Christophe Lourdelet
# 4  A secret government agency recruits some of th...            David Ayer
#
#                                               Actors  Year  Runtime (Minutes)  \
# ...

# %%
#Comedy movies
data.columns
# Out:
# Index(['Rank', 'Title', 'Genre', 'Description', 'Director', 'Actors', 'Year',
#        'Runtime (Minutes)', 'Rating', 'Votes', 'Revenue (Millions)',
#        'Metascore', 'rating_cat'],
#       dtype='object')

# %%
data['Genre'].dtype
# Out:
# dtype('O')

# %%
#object datatype supports string methods
data['Genre'].str.contains('Comedy',case=False)
# Out:
# 0      False
# 1      False
# 2      False
# 3       True
# 4      False
#        ...
# 993    False
# 994     True
# 996    False
# 997    False
# 999     True
# Name: Genre, Length: 838, dtype: bool

# %%
top_10_comedy=data[data['Genre'].str.contains('Comedy',case=False)]
top_10_comedy_movies=top_10_comedy.nlargest(10,'Rating')[['Title','Genre','Rating']].set_index('Title')
top_10_comedy_movies
# Out:
#                                                Genre  Rating
# Title
# The Intouchables              Biography,Comedy,Drama     8.6
# 3 Idiots                                Comedy,Drama     8.4
# La La Land                        Comedy,Drama,Music     8.3
# Up                        Animation,Adventure,Comedy     8.3
# Toy Story 3               Animation,Adventure,Comedy     8.3
# The Wolf of Wall Street       Biography,Comedy,Crime     8.2
# Inside Out                Animation,Adventure,Comedy     8.2
# PK                              Comedy,Drama,Romance     8.2
# Zootopia                  Animation,Adventure,Comedy     8.1
# The Grand Budapest Hotel      Adventure,Comedy,Drama     8.1

# %%
sns.barplot(x='Rating',y=top_10_comedy_movies.index,data=top_10_comedy_movies)
# Out:
# <Axes: xlabel='Rating', ylabel='Title'>

# %%
#Top 5 rated movies
top_5=data.nlargest(5,'Rating')[['Title','Director','Rating',]].set_index('Title')
sns.barplot(x='Rating',y=top_5.index,data=top_5)
# Out:
# <Axes: xlabel='Rating', ylabel='Title'>

# %%
#top 10 genre based on rating
top_genres = data.groupby('Genre').agg({'Rating':'sum'}).sort_values(by='Rating',ascending=False).head(10)
top_genres
# Out:
#                             Rating
# Genre
# Action,Adventure,Sci-Fi      336.2
# Drama                        204.5
# Comedy,Drama,Romance         202.3
# Drama,Romance                190.7
# Animation,Adventure,Comedy   187.6
# Comedy,Drama                 169.9
# Action,Adventure,Fantasy     160.4
# Comedy                       158.3
# Comedy,Romance               136.6
# Crime,Drama,Mystery          128.3

# %%
#Does Rating Affect The Revenue?
sns.scatterplot(x='Rating',y='Revenue (Millions)',data=data)
# Out:
# <Axes: xlabel='Rating', ylabel='Revenue (Millions)'>

# %%
#Directors with more movie rating
data.Director.value_counts().head(10).plot.bar(figsize=(12,4))
# Out:
# <Axes: xlabel='Director'>

# %%
#Top 10 Directors¶
data.Director.value_counts()[:10].plot.pie(autopct='%1.1f%%',figsize=(10,10))
# Out:
# <Axes: ylabel='count'>

# %%
#chris patt's movies
chris=data[data['Actors'].str.contains('Chris Pratt',case=False)]
chris[['Year','Title','Genre','Director','Description','Actors']]
# Out:
#      Year                    Title                       Genre  \
# 0    2014  Guardians of the Galaxy     Action,Adventure,Sci-Fi
# 9    2016               Passengers     Adventure,Drama,Romance
# 38   2016    The Magnificent Seven    Action,Adventure,Western
# 85   2015           Jurassic World     Action,Adventure,Sci-Fi
# 384  2014           The Lego Movie  Animation,Action,Adventure
# 406  2012         Zero Dark Thirty      Drama,History,Thriller
#
#             Director                                        Description  \
# 0         James Gunn  A group of intergalactic criminals are forced ...
# 9      Morten Tyldum  A spacecraft traveling to a distant colony pla...
# 38     Antoine Fuqua  Seven gunmen in the old west gradually come to...
# 85   Colin Trevorrow  A new theme park, built on the original site o...
# 384        Phil Lord  An ordinary Lego construction worker, thought ...
# 406  Kathryn Bigelow  A chronicle of the decade-long hunt for al-Qae...
#
# ...

# %%
# Movies per year
sns.set_style("darkgrid")
plt.figure(figsize = (15,10))
data['Year'].value_counts().sort_index().plot(kind = "line" , marker = "o" , color = "g" , mec = "r" , mfc = "black")
plt.xticks(np.arange(2000,2022,4) , rotation = 90 , fontsize = 15)
plt.xlabel("Year" , fontsize = 20)
plt.ylabel("Movies Released" , fontsize = 20)
plt.title("Trend Line - Movies Released Per Year" , fontsize = 30)
plt.show()
